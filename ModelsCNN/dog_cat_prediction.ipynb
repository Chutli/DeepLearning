# %% [markdown]
# # Chapter 5: Transfer Learning
# ## Ex1: Pre-trained models - Prediction Dog or Cat
# * Sử dụng model vừa xây dựng để dự đoán một hình ảnh là Dog/Cat.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/LDS8_K275_ONLINE_NGUYENTHIKIMHOANG/Week_3/Chapter5
# Out:
# /content/drive/My Drive/LDS8_K275_ONLINE_NGUYENTHIKIMHOANG/Week_3/Chapter5

# %%
from tensorflow.keras.models import load_model
classifier = load_model('dog_cat_vgg16.h5')

import numpy as np
from tensorflow.keras.preprocessing import image

# %%
def print_result(test_image):
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image,axis=0)
  result = classifier.predict(test_image)
  print(result)
  # traing_set.class_indices
  if result[0][0] > result[0][1]:
    prediction ='cat'
  else:
    prediction = 'dog'
  print(prediction)

# %%
test_image =image.load_img('dataset/single_prediction/dog1.jpg',
                           target_size = (224,224))
print_result(test_image)
# Out:
# [[0.00643987 0.9935601 ]]
# dog

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
