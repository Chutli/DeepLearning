# %% [markdown]
# # Chapter 5: Transfer Learning
# ## Ex1: Pre-trained models
# * Tạo 1 bộ dữ liệu Dog/Cat nhỏ (khoảng 300 hình) lấy ngẫu nhiên từ bộ dữ liệu Dog/Cat đã cung cấp ở Chapter 4
# * Chọn 1 pre-trained model - VGG16 - để xây dựng model dự đoán Dog/Cat
# * Lưu model vừa xây dựng xong.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/LDS8_K275_ONLINE_NGUYENTHIKIMHOANG/Week_3/Chapter5
# Out:
# /content/drive/My Drive/LDS8_K275_ONLINE_NGUYENTHIKIMHOANG/Week_3/Chapter5

# %%
from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras import backend as k
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

# %% [markdown]
# ## Small dataset ~ 300 images: 2 classes
#
# ### Strategy:  4
#
# VGG16: image(224,224)

# %%
img_width,img_height = 224,224
train_data_dir = 'dataset/training_set'
validation_data_dir = 'dataset/test_set'

# %%
# http://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG16
model = applications.VGG16(weights = 'imagenet',
                           include_top = False, #whether to include the 3 fully-connected layers at the top of the network
                           input_shape = (img_width,img_height,3))

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## New dataset is small and similar to original dataset

# %%
# so lets freeze all the VGG16 layers and train only the classifier
for layer in model.layers:
  layer.trainable = False

# %%
# adding custom layers - ANN
x = model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1024,activation = 'relu')(x)
predictions = Dense(2, activation = 'softmax')(x)

# %%
# creating the final model
model_final = Model(inputs = model.input,outputs = predictions)

# %%
# compile the model
model_final.compile(loss = 'categorical_crossentropy',
                    optimizer = optimizers.SGD(lr=0.0001,momentum=0.9),
                    metrics = ['accuracy'])

# %%
# Initiate the train and test generators with data Augumentation
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip = True,
                                   fill_mode = 'nearest',
                                   zoom_range = 0.3,
                                   width_shift_range = 0.3,
                                   height_shift_range=0.3,
                                   rotation_range = 30)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                    target_size = (img_height,
                                                                   img_width),
                                                    batch_size = 32,
                                                    class_mode = 'categorical')

validation_generator = test_datagen.flow_from_directory(validation_data_dir,
                                                        target_size = (img_height,
                                                                       img_width),
                                                        class_mode = 'categorical')
# Out:
# Found 200 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
# save the model according to the conditions
checkpoint = ModelCheckpoint('Checkpoint_vgg16.h5',
                             monitor = 'val_loss',
                             verbose = 1,
                             save_best_only=True,
                             save_weights_only=False,
                             mode= 'auto',
                             save_freq = 1)
early = EarlyStopping(monitor = 'val_loss',
                      min_delta = 0,
                      patience = 10,
                      verbose = 1,
                      mode = 'auto')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
callbacks = [EarlyStopping(monitor='val_loss',patience=5),ModelCheckpoint('Checkpoint_vgg16.h5',save_best_only=True)]

# %%
import datetime

# %%
t0 = datetime.datetime.now()
print(t0)
# Out:
# 2022-06-01 04:21:27.715593

# %%
# Train the model
history = model_final.fit(train_generator,
                steps_per_epoch = len(train_generator),
                epochs = 100,
                validation_data = validation_generator,
                validation_steps = len(validation_generator),
                verbose = 1,
                callbacks = callbacks)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 641ms/step - loss: 0.7776 - accuracy: 0.4950 - val_loss: 0.7752 - val_accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 4s 583ms/step - loss: 0.7879 - accuracy: 0.4800 - val_loss: 0.7459 - val_accuracy: 0.4900
# Epoch 3/100
# 7/7 [==============================] - 4s 591ms/step - loss: 0.7339 - accuracy: 0.4700 - val_loss: 0.7102 - val_accuracy: 0.4900
# Epoch 4/100
# 7/7 [==============================] - 4s 591ms/step - loss: 0.7140 - accuracy: 0.5600 - val_loss: 0.6831 - val_accuracy: 0.5500
# Epoch 5/100
# 7/7 [==============================] - 4s 601ms/step - loss: 0.7180 - accuracy: 0.5450 - val_loss: 0.6667 - val_accuracy: 0.5600
# Epoch 6/100
# 7/7 [==============================] - 4s 587ms/step - loss: 0.7119 - accuracy: 0.5550 - val_loss: 0.6539 - val_accuracy: 0.5800
# Epoch 7/100
# 7/7 [==============================] - 4s 589ms/step - loss: 0.7008 - accuracy: 0.5450 - val_loss: 0.6432 - val_accuracy: 0.6200
# Epoch 8/100
# 7/7 [==============================] - 4s 588ms/step - loss: 0.6854 - accuracy: 0.5900 - val_loss: 0.6351 - val_accuracy: 0.6100
# Epoch 9/100
# 7/7 [==============================] - 4s 613ms/step - loss: 0.6548 - accuracy: 0.6050 - val_loss: 0.6095 - val_accuracy: 0.6800
# Epoch 10/100
# 7/7 [==============================] - 5s 686ms/step - loss: 0.6923 - accuracy: 0.5950 - val_loss: 0.5935 - val_accuracy: 0.7500
# Epoch 11/100
# 7/7 [==============================] - 4s 584ms/step - loss: 0.6786 - accuracy: 0.6200 - val_loss: 0.5913 - val_accuracy: 0.7200
# Epoch 12/100
# 7/7 [==============================] - 4s 614ms/step - loss: 0.6666 - accuracy: 0.6100 - val_loss: 0.5835 - val_accuracy: 0.7500
# Epoch 13/100
# 7/7 [==============================] - 4s 545ms/step - loss: 0.6630 - accuracy: 0.6300 - val_loss: 0.6013 - val_accuracy: 0.6300
# Epoch 14/100
# 7/7 [==============================] - 4s 612ms/step - loss: 0.6606 - accuracy: 0.5950 - val_loss: 0.5642 - val_accuracy: 0.7900
# Epoch 15/100
# 7/7 [==============================] - 4s 661ms/step - loss: 0.6369 - accuracy: 0.6500 - val_loss: 0.5626 - val_accuracy: 0.7500
# Epoch 16/100
# 7/7 [==============================] - 3s 487ms/step - loss: 0.6403 - accuracy: 0.5950 - val_loss: 0.5978 - val_accuracy: 0.6300
# Epoch 17/100
# 7/7 [==============================] - 4s 600ms/step - loss: 0.6365 - accuracy: 0.6500 - val_loss: 0.5362 - val_accuracy: 0.8200
# Epoch 18/100
# 7/7 [==============================] - 4s 602ms/step - loss: 0.6563 - accuracy: 0.6250 - val_loss: 0.5282 - val_accuracy: 0.8100
# Epoch 19/100
# 7/7 [==============================] - 3s 488ms/step - loss: 0.6506 - accuracy: 0.6450 - val_loss: 0.5673 - val_accuracy: 0.6700
# Epoch 20/100
# 7/7 [==============================] - 4s 605ms/step - loss: 0.5968 - accuracy: 0.7000 - val_loss: 0.5212 - val_accuracy: 0.8100
# Epoch 21/100
# 7/7 [==============================] - 4s 589ms/step - loss: 0.5957 - accuracy: 0.6700 - val_loss: 0.5209 - val_accuracy: 0.8100
# Epoch 22/100
# 7/7 [==============================] - 3s 549ms/step - loss: 0.6237 - accuracy: 0.6650 - val_loss: 0.5745 - val_accuracy: 0.6700
# Epoch 23/100
# 7/7 [==============================] - 4s 599ms/step - loss: 0.5693 - accuracy: 0.7050 - val_loss: 0.5132 - val_accuracy: 0.8200
# Epoch 24/100
# 7/7 [==============================] - 3s 467ms/step - loss: 0.5858 - accuracy: 0.7000 - val_loss: 0.5218 - val_accuracy: 0.7800
# Epoch 25/100
# 7/7 [==============================] - 4s 597ms/step - loss: 0.5616 - accuracy: 0.6900 - val_loss: 0.5108 - val_accuracy: 0.7900
# Epoch 26/100
# 7/7 [==============================] - 4s 496ms/step - loss: 0.5485 - accuracy: 0.7550 - val_loss: 0.5366 - val_accuracy: 0.7200
# Epoch 27/100
# 7/7 [==============================] - 3s 553ms/step - loss: 0.6362 - accuracy: 0.6050 - val_loss: 0.5246 - val_accuracy: 0.7300
# Epoch 28/100
# 7/7 [==============================] - 4s 634ms/step - loss: 0.5460 - accuracy: 0.7300 - val_loss: 0.4920 - val_accuracy: 0.8000
# Epoch 29/100
# 7/7 [==============================] - 4s 494ms/step - loss: 0.6281 - accuracy: 0.6500 - val_loss: 0.5224 - val_accuracy: 0.7300
# Epoch 30/100
# 7/7 [==============================] - 4s 500ms/step - loss: 0.5507 - accuracy: 0.7250 - val_loss: 0.5611 - val_accuracy: 0.6800
# Epoch 31/100
# 7/7 [==============================] - 4s 604ms/step - loss: 0.5546 - accuracy: 0.7100 - val_loss: 0.4709 - val_accuracy: 0.8400
# Epoch 32/100
# 7/7 [==============================] - 4s 486ms/step - loss: 0.5957 - accuracy: 0.6950 - val_loss: 0.5416 - val_accuracy: 0.7100
# Epoch 33/100
# 7/7 [==============================] - 3s 483ms/step - loss: 0.5724 - accuracy: 0.6850 - val_loss: 0.5391 - val_accuracy: 0.7100
# Epoch 34/100
# 7/7 [==============================] - 4s 538ms/step - loss: 0.5608 - accuracy: 0.7050 - val_loss: 0.4753 - val_accuracy: 0.8300
# Epoch 35/100
# 7/7 [==============================] - 4s 521ms/step - loss: 0.5431 - accuracy: 0.7150 - val_loss: 0.5142 - val_accuracy: 0.7400
# Epoch 36/100
# 7/7 [==============================] - 4s 490ms/step - loss: 0.5429 - accuracy: 0.7250 - val_loss: 0.4859 - val_accuracy: 0.7700

# %%
t1 = datetime.datetime.now()
print('Thoi gian chay mo hinh: ', t1-t0)
# Out:
# Thoi gian chay mo hinh:  0:02:25.365233

# %%
import pandas as pd

# %%
history_df = pd.DataFrame(history.history)
history_df.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 31  0.595738     0.695  0.541617          0.71
# 32  0.572380     0.685  0.539057          0.71
# 33  0.560795     0.705  0.475255          0.83
# 34  0.543088     0.715  0.514249          0.74
# 35  0.542864     0.725  0.485913          0.77

# %%
# save model
from tensorflow.keras.models import load_model
# creates a HDF5 file 'my_model.h5'
model_final.save('dog_cat_vgg16.h5')
print('Save!!!')
# Out:
# Save!!!
